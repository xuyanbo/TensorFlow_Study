# %%
# -*- coding: utf-8 -*-

import numpy as np
import tensorflow as tf

import matplotlib as mpl
from matplotlib import pyplot as plt
# %matplotlib inline

# LSTM中隐藏节点的个数
HIDDEN_SIZE = 30
# LSTM的层数
NUM_LAYERS = 2

# 循环神经网络的训练序列长度
TIMESTEPS = 10
# 训练轮数
TRAINING_STEPS = 10000
# batch大小
BATCH_SIZE = 32

# 训练数据个数
TRAINING_EXAMPLES = 10000
# 测试数据个数
TESTING_EXAMPLES = 1000
# 采样间隔
SAMPLE_GAP = 0.01

def generate_data(seq):
    X = []
    y = []
    for i in range(len(seq) - TIMESTEPS):
        X.append([seq[i:i+TIMESTEPS]])
        y.append([seq[i+TIMESTEPS]])
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def lstm_model(X, y, is_training):
    cell = tf.nn.rnn_cell.MultiRNNCell([
        tf.nn.rnn_cell.BasicLSTMCell(HIDDEN_SIZE) 
        for _ in range(NUM_LAYERS)])
    # output维度[batch_size, time, HIDDEN_SIZE]
    outputs,_ = tf.nn.dynamic_rnn(cell, inputs=X, dtype=tf.float32)
    # 只关注最后一个时刻输出结果
    output = outputs[:,-1,:]
    # 对LSTM网络的输出加一层全连接层并计算损失
    predictions = tf.contrib.layers.fully_connected(
        output, 1, activation_fn=None)
    # 只在训练时计算损失函数和优化步骤
    if not is_training:
        return predictions, None, None
    
    # 计算损失函数
    loss = tf.losses.mean_squared_error(labels=y, predictions=predictions)
    # 创建模型优化器
    train_op = tf.contrib.layers.optimize_loss(
        loss, tf.train.get_global_step(), 
        optimizer="Adagrad", learning_rate=0.1)
    
    return predictions, loss, train_op

def train(sess, train_X, train_y):
    ds = tf.data.Dataset.from_tensor_slices((train_X, train_y))
    ds = ds.repeat().shuffle(1000).batch(BATCH_SIZE)
    X, y = ds.make_one_shot_iterator().get_next()
    
    # 调用模型
    with tf.variable_scope("model"):
        predictions, loss, train_op = lstm_model(X, y, True)
    
    # 初始化变量
    sess.run(tf.global_variables_initializer())
    for i in range(TRAINING_STEPS):
        _, l = sess.run([train_op, loss])
        if i % 100 == 0:
            print("train step:" + str(i) + ",loss:" + str(l))
        
def run_eval(sess, test_X, test_y):
    ds = tf.data.Dataset.from_tensor_slices((test_X, test_y))
    ds = ds.batch(1)
    X, y = ds.make_one_shot_iterator().get_next()
    
    # 调用模型得到计算结果
    with tf.variable_scope("model", reuse=True):
        prediction, _, _ = lstm_model(X, [0.0], False)
    
    # 将预测结果存入一个数组
    predictions = []
    labels = []
    for i in range(TESTING_EXAMPLES):
        p, l = sess.run([prediction, y])
        predictions.append(p[0][0])
        labels.append(l)
    
    preditions = np.array(predictions).squeeze()
    labels = np.array(labels).squeeze()
    rmse = np.sqrt(((predictions-labels)**2).mean(axis=0))
    print(rmse)
    print("Mean Square Error is:%f" % rmse)
    
    plt.figure()
    plt.plot(predictions, label='predictions')
    plt.plot(labels, label='real_sin')
    plt.legend()
    plt.show()
 
tf.reset_default_graph()
test_start = (TRAINING_EXAMPLES + TIMESTEPS) * SAMPLE_GAP
test_end = test_start + (TESTING_EXAMPLES + TIMESTEPS) * SAMPLE_GAP
train_X, train_y = generate_data(np.sin(np.linspace(
    0, test_start, TRAINING_EXAMPLES+TIMESTEPS, dtype=np.float32)))
test_X, test_y = generate_data(np.sin(np.linspace(
    test_start, test_end, TESTING_EXAMPLES+TIMESTEPS, dtype=np.float32)))

with tf.Session() as sess:
    # 训练模型
    train(sess, train_X, train_y)
    # 预测模型
    run_eval(sess, test_X, test_y)
# Out:
# train step:0,loss:0.48358196
# train step:100,loss:0.0042998684
# train step:200,loss:0.0036556069
# train step:300,loss:0.0033900097
# train step:400,loss:0.0027218987
# train step:500,loss:0.0024717238
# train step:600,loss:0.0021009962
# train step:700,loss:0.0016476831
# train step:800,loss:0.0014351674
# train step:900,loss:0.0010400319
# train step:1000,loss:0.0008180183
# train step:1100,loss:0.0010129218
# train step:1200,loss:0.00065694144
# train step:1300,loss:0.0004178915
# train step:1400,loss:0.00081562455
# train step:1500,loss:0.00044815362
# train step:1600,loss:0.0004661754
# train step:1700,loss:0.0004734279
# train step:1800,loss:0.00042215316
# train step:1900,loss:0.00031826113
# train step:2000,loss:0.00029583983
# train step:2100,loss:0.00024788696
# train step:2200,loss:0.00011650659
# train step:2300,loss:0.00011670098
# train step:2400,loss:0.00016229699
# train step:2500,loss:0.00013339239
# train step:2600,loss:5.99265e-05
# train step:2700,loss:7.6323806e-05
# train step:2800,loss:6.459891e-05
# train step:2900,loss:4.7360554e-05
# train step:3000,loss:4.536657e-05
# train step:3100,loss:3.842818e-05
# train step:3200,loss:4.403275e-05
# train step:3300,loss:3.061336e-05
# train step:3400,loss:1.96501e-05
# train step:3500,loss:2.2084343e-05
# train step:3600,loss:2.4882967e-05
# train step:3700,loss:2.3584551e-05
# train step:3800,loss:1.50326205e-05
# train step:3900,loss:1.4019187e-05
# train step:4000,loss:1.1676248e-05
# train step:4100,loss:1.4246925e-05
# train step:4200,loss:8.235445e-06
# train step:4300,loss:1.4126118e-05
# train step:4400,loss:9.379344e-06
# train step:4500,loss:6.647262e-06
# train step:4600,loss:6.245165e-06
# train step:4700,loss:6.627498e-06
# train step:4800,loss:6.1201417e-06
# train step:4900,loss:5.366478e-06
# train step:5000,loss:6.724047e-06
# train step:5100,loss:6.136249e-06
# train step:5200,loss:5.560211e-06
# train step:5300,loss:5.6514236e-06
# train step:5400,loss:3.920931e-06
# train step:5500,loss:3.0925169e-06
# train step:5600,loss:5.2592236e-06
# train step:5700,loss:5.0912176e-06
# train step:5800,loss:3.4918005e-06
# train step:5900,loss:6.7251895e-06
# train step:6000,loss:4.1469234e-06
# train step:6100,loss:2.6431176e-06
# train step:6200,loss:3.3855467e-06
# train step:6300,loss:3.9358647e-06
# train step:6400,loss:4.52627e-06
# train step:6500,loss:2.7278777e-06
# train step:6600,loss:4.2401666e-06
# train step:6700,loss:2.8391132e-06
# train step:6800,loss:4.024418e-06
# train step:6900,loss:4.0251016e-06
# train step:7000,loss:3.6501215e-06
# train step:7100,loss:4.074088e-06
# train step:7200,loss:2.7660908e-06
# train step:7300,loss:5.9707686e-06
# train step:7400,loss:3.5898543e-06
# train step:7500,loss:2.4684032e-06
# train step:7600,loss:4.3006494e-06
# train step:7700,loss:2.8269596e-06
# train step:7800,loss:6.039424e-06
# train step:7900,loss:4.1240446e-06
# train step:8000,loss:3.1739214e-06
# train step:8100,loss:4.226831e-06
# train step:8200,loss:4.3259406e-06
# train step:8300,loss:2.1230849e-06
# train step:8400,loss:3.2829134e-06
# train step:8500,loss:2.4722099e-06
# train step:8600,loss:6.513863e-06
# train step:8700,loss:2.2340412e-06
# train step:8800,loss:3.0429524e-06
# train step:8900,loss:2.6457303e-06
# train step:9000,loss:3.3665947e-06
# train step:9100,loss:4.2344655e-06
# train step:9200,loss:4.2560373e-06
# train step:9300,loss:3.0023418e-06
# train step:9400,loss:4.817404e-06
# train step:9500,loss:3.2912226e-06
# train step:9600,loss:2.5962477e-06
# train step:9700,loss:2.7136493e-06
# train step:9800,loss:3.756376e-06
# train step:9900,loss:3.5560377e-06
# 0.0018565198
# Mean Square Error is:0.001857
